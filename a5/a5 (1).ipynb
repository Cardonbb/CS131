# %% [markdown]
# found so i can do in google colab

# %%
# Install Java, Spark 3.4.1 (working stable), and findspark
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-3.4.1/spark-3.4.1-bin-hadoop3.tgz
# !tar xf spark-3.4.1-bin-hadoop3.tgz
# !pip install -q findspark

# Set environment variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.4.1-bin-hadoop3"

# Initialize findspark
import findspark
findspark.init()
# Out:
# Get:1 file:/etc/apt/mirrors/debian.list Mirrorlist [30 B]
# Get:5 file:/etc/apt/mirrors/debian-security.list Mirrorlist [39 B]
# Hit:7 https://storage.googleapis.com/goog-dataproc-bigtop-repo-northamerica-northeast2/2_2_deb12_20250312_125600-RC01 dataproc InRelease
# Get:8 https://packages.cloud.google.com/apt google-compute-engine-bookworm-stable InRelease [1321 B]
# Hit:9 https://storage.googleapis.com/dataproc-bigtop-repo/2_2_deb12_20250312_125600-RC01 dataproc InRelease
# Get:10 https://packages.cloud.google.com/apt cloud-sdk-bookworm InRelease [1654 B]
# Get:11 https://packages.cloud.google.com/apt google-compute-engine-bookworm-stable/main amd64 Packages [3129 B]
# Get:12 https://packages.cloud.google.com/apt cloud-sdk-bookworm/main all Packages [1725 kB]
# Get:13 https://packages.cloud.google.com/apt cloud-sdk-bookworm/main amd64 Packages [3837 kB]
# Ign:14 https://repo.mysql.com/apt/debian bookworm InRelease
# Ign:15 https://packages.adoptium.net/artifactory/deb bookworm InRelease
# Ign:16 https://download.docker.com/linux/debian bookworm InRelease
# Ign:2 https://deb.debian.org/debian bookworm InRelease
# Ign:3 https://deb.debian.org/debian bookworm-updates InRelease
# Ign:4 https://deb.debian.org/debian bookworm-backports InRelease
# Ign:6 https://deb.debian.org/debian-security bookworm-security InRelease
# Ign:14 https://repo.mysql.com/apt/debian bookworm InRelease
# Ign:15 https://packages.adoptium.net/artifactory/deb bookworm InRelease
# Ign:16 https://download.docker.com/linux/debian bookworm InRelease
# Ign:2 https://deb.debian.org/debian bookworm InRelease
# Ign:3 https://deb.debian.org/debian bookworm-updates InRelease
# Ign:4 https://deb.debian.org/debian bookworm-backports InRelease
# Ign:6 https://deb.debian.org/debian-security bookworm-security InRelease
# Ign:14 https://repo.mysql.com/apt/debian bookworm InRelease
# Ign:15 https://packages.adoptium.net/artifactory/deb bookworm InRelease
# Ign:16 https://download.docker.com/linux/debian bookworm InRelease
# Ign:2 https://deb.debian.org/debian bookworm InRelease
# Ign:3 https://deb.debian.org/debian bookworm-updates InRelease
# Ign:4 https://deb.debian.org/debian bookworm-backports InRelease
# Ign:6 https://deb.debian.org/debian-security bookworm-security InRelease
# Err:14 https://repo.mysql.com/apt/debian bookworm InRelease
#   Cannot initiate the connection to repo.mysql.com:443 (2600:140a:5000:c8a::1d68). - connect (101: Network is unreachable) Cannot initiate the connection to repo.mysql.com:443 (2600:140a:5000:c83::1d68). - connect (101: Network is unreachable) Could not connect to repo.mysql.com:443 (184.26.205.45), connection timed out
# Err:15 https://packages.adoptium.net/artifactory/deb bookworm InRelease
#   Cannot initiate the connection to packages.adoptium.net:443 (2606:4700::6812:1442). - connect (101: Network is unreachable) Cannot initiate the connection to packages.adoptium.net:443 (2606:4700::6812:1542). - connect (101: Network is unreachable) Could not connect to packages.adoptium.net:443 (104.18.20.66), connection timed out Could not connect to packages.adoptium.net:443 (104.18.21.66), connection timed out
# Err:16 https://download.docker.com/linux/debian bookworm InRelease
#   Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:5800:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:7400:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:2600:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:6400:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:2200:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:5c00:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:1000:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:4400:3:db06:4200:93a1). - connect (101: Network is unreachable) Could not connect to download.docker.com:443 (3.164.92.64), connection timed out Could not connect to download.docker.com:443 (3.164.92.31), connection timed out Could not connect to download.docker.com:443 (3.164.92.78), connection timed out Could not connect to download.docker.com:443 (3.164.92.71), connection timed out
# Err:2 https://deb.debian.org/debian bookworm InRelease
#   Cannot initiate the connection to debian.map.fastly.net:443 (2a04:4e42::644). - connect (101: Network is unreachable) Cannot initiate the connection to debian.map.fastly.net:443 (2a04:4e42:200::644). - connect (101: Network is unreachable) Cannot initiate the connection to debian.map.fastly.net:443 (2a04:4e42:400::644). - connect (101: Network is unreachable) Cannot initiate the connection to debian.map.fastly.net:443 (2a04:4e42:600::644). - connect (101: Network is unreachable) Could not connect to debian.map.fastly.net:443 (151.101.2.132), connection timed out Could not connect to debian.map.fastly.net:443 (151.101.66.132), connection timed out Could not connect to debian.map.fastly.net:443 (151.101.130.132), connection timed out Could not connect to debian.map.fastly.net:443 (151.101.194.132), connection timed out Cannot initiate the connection to deb.debian.org:443 (2a04:4e42::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:200::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:400::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:600::644). - connect (101: Network is unreachable)
# Err:3 https://deb.debian.org/debian bookworm-updates InRelease
#   Cannot initiate the connection to deb.debian.org:443 (2a04:4e42::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:200::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:400::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:600::644). - connect (101: Network is unreachable)
# Err:4 https://deb.debian.org/debian bookworm-backports InRelease
#   Cannot initiate the connection to deb.debian.org:443 (2a04:4e42::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:200::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:400::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:600::644). - connect (101: Network is unreachable)
# Err:6 https://deb.debian.org/debian-security bookworm-security InRelease
#   Cannot initiate the connection to deb.debian.org:443 (2a04:4e42::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:200::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:400::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:600::644). - connect (101: Network is unreachable)
# Fetched 5568 kB in 38s (146 kB/s)
# Reading package lists... Done
# W: https://storage.googleapis.com/goog-dataproc-bigtop-repo-northamerica-northeast2/2_2_deb12_20250312_125600-RC01/dists/dataproc/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# W: https://storage.googleapis.com/dataproc-bigtop-repo/2_2_deb12_20250312_125600-RC01/dists/dataproc/InRelease: Key is stored in legacy trusted.gpg keyring (/etc/apt/trusted.gpg), see the DEPRECATION section in apt-key(8) for details.
# W: Failed to fetch https://packages.adoptium.net/artifactory/deb/dists/bookworm/InRelease  Cannot initiate the connection to packages.adoptium.net:443 (2606:4700::6812:1442). - connect (101: Network is unreachable) Cannot initiate the connection to packages.adoptium.net:443 (2606:4700::6812:1542). - connect (101: Network is unreachable) Could not connect to packages.adoptium.net:443 (104.18.20.66), connection timed out Could not connect to packages.adoptium.net:443 (104.18.21.66), connection timed out
# W: Failed to fetch mirror+file:/etc/apt/mirrors/debian.list/dists/bookworm/InRelease  Cannot initiate the connection to debian.map.fastly.net:443 (2a04:4e42::644). - connect (101: Network is unreachable) Cannot initiate the connection to debian.map.fastly.net:443 (2a04:4e42:200::644). - connect (101: Network is unreachable) Cannot initiate the connection to debian.map.fastly.net:443 (2a04:4e42:400::644). - connect (101: Network is unreachable) Cannot initiate the connection to debian.map.fastly.net:443 (2a04:4e42:600::644). - connect (101: Network is unreachable) Could not connect to debian.map.fastly.net:443 (151.101.2.132), connection timed out Could not connect to debian.map.fastly.net:443 (151.101.66.132), connection timed out Could not connect to debian.map.fastly.net:443 (151.101.130.132), connection timed out Could not connect to debian.map.fastly.net:443 (151.101.194.132), connection timed out Cannot initiate the connection to deb.debian.org:443 (2a04:4e42::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:200::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:400::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:600::644). - connect (101: Network is unreachable)
# W: Failed to fetch mirror+file:/etc/apt/mirrors/debian.list/dists/bookworm-updates/InRelease  Cannot initiate the connection to deb.debian.org:443 (2a04:4e42::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:200::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:400::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:600::644). - connect (101: Network is unreachable)
# W: Failed to fetch mirror+file:/etc/apt/mirrors/debian.list/dists/bookworm-backports/InRelease  Cannot initiate the connection to deb.debian.org:443 (2a04:4e42::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:200::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:400::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:600::644). - connect (101: Network is unreachable)
# W: Failed to fetch mirror+file:/etc/apt/mirrors/debian-security.list/dists/bookworm-security/InRelease  Cannot initiate the connection to deb.debian.org:443 (2a04:4e42::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:200::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:400::644). - connect (101: Network is unreachable) Cannot initiate the connection to deb.debian.org:443 (2a04:4e42:600::644). - connect (101: Network is unreachable)
# W: Failed to fetch https://download.docker.com/linux/debian/dists/bookworm/InRelease  Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:5800:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:7400:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:2600:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:6400:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:2200:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:5c00:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:1000:3:db06:4200:93a1). - connect (101: Network is unreachable) Cannot initiate the connection to download.docker.com:443 (2600:9000:2843:4400:3:db06:4200:93a1). - connect (101: Network is unreachable) Could not connect to download.docker.com:443 (3.164.92.64), connection timed out Could not connect to download.docker.com:443 (3.164.92.31), connection timed out Could not connect to download.docker.com:443 (3.164.92.78), connection timed out Could not connect to download.docker.com:443 (3.164.92.71), connection timed out
# W: Failed to fetch https://repo.mysql.com/apt/debian/dists/bookworm/InRelease  Cannot initiate the connection to repo.mysql.com:443 (2600:140a:5000:c8a::1d68). - connect (101: Network is unreachable) Cannot initiate the connection to repo.mysql.com:443 (2600:140a:5000:c83::1d68). - connect (101: Network is unreachable) Could not connect to repo.mysql.com:443 (184.26.205.45), connection timed out
# W: Some index files failed to download. They have been ignored, or old ones used instead.
# E: Package 'openjdk-11-jdk-headless' has no installation candidate

# %% [markdown]
# import

# %%
from pyspark.sql import SparkSession
from time import time
import matplotlib.pyplot as plt
from pyspark.sql.functions import regexp_replace, col
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.regression import LinearRegression
import pandas as pd
import numpy as np


spark = SparkSession.builder.appName("a5").getOrCreate()

# %% [markdown]
# dataset

# %%
import kagglehub

# Download latest version
file = kagglehub.dataset_download("danielcalvoglez/us-tariffs-2025")

print("Path to dataset files:", file)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/danielcalvoglez/us-tariffs-2025?dataset_version_number=2...
# 100%|██████████| 8.89k/8.89k [00:00<00:00, 10.7MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/danielcalvoglez/us-tariffs-2025/versions/2

# %%
df = spark.read.csv(file, header=True, inferSchema=True, sep=";")
df.show()
# Out:
# +-------------------+---------------+---------------+-------------------------------+---------------------+--------------+----------+
# |            Country|US 2024 Deficit|US 2024 Exports|US 2024 Imports (Customs Basis)|Trump Tariffs Alleged|Trump Response|Population|
# +-------------------+---------------+---------------+-------------------------------+---------------------+--------------+----------+
# |        Afghanistan|          -11.1|           11.4|                           22.6|                  49%|           25%|  41454761|
# |            Albania|           13.4|          141.7|                          128.3|                  10%|           10%|   2745972|
# |            Algeria|      -1,447.10|       1,014.50|                       2,461.60|                  59%|           29%|  46164219|
# |            Andorra|            1.5|            4.9|                            3.4|                  10%|           10%|     80856|
# |             Angola|      -1,186.90|          682.4|                       1,869.20|                  63%|           32%|  36749906|
# |           Anguilla|           71.3|           72.5|                            1.2|                  10%|           10%|      NULL|
# |Antigua and Barbuda|            550|          573.8|                           23.8|                  10%|           10%|     93316|
# |          Argentina|       2,078.80|       9,171.00|                       7,092.20|                  10%|           10%|  45538401|
# |            Armenia|           39.2|          160.8|                          121.6|                  10%|           10%|   2990900|
# |              Aruba|          714.8|          725.5|                           10.7|                  10%|           10%|    107359|
# |         Australia*|      17,907.80|      34,593.30|                      16,685.50|                  10%|           10%|  26658948|
# |         Azerbaijan|           97.3|          255.1|                          157.8|                  10%|           10%|  10153958|
# |            Bahamas|       3,847.40|       5,639.70|                       1,792.40|                  10%|           10%|    399440|
# |           Bahrain*|          441.9|       1,646.20|                       1,204.30|                  10%|           10%|   1577059|
# |         Bangladesh|      -6,151.80|       2,214.00|                       8,365.80|                  74%|           37%| 171466990|
# |           Barbados|            724|          772.6|                           48.6|                  10%|           10%|    282336|
# |            Belarus|           -9.4|           10.6|                             20|                  47%|           24%|   9178298|
# |             Belize|          509.3|          590.4|                           81.1|                  10%|           10%|    411106|
# |              Benin|          167.8|          216.4|                           48.6|                  10%|           10%|  14111034|
# |            Bermuda|          517.1|          540.4|                           23.3|                  10%|           10%|     64698|
# +-------------------+---------------+---------------+-------------------------------+---------------------+--------------+----------+
# only showing top 20 rows

# %%
df.columns
# Out:
# ['Country',
#  'US 2024 Deficit',
#  'US 2024 Exports',
#  'US 2024 Imports (Customs Basis)',
#  'Trump Tariffs Alleged',
#  'Trump Response',
#  'Population']

# %%
df = df.withColumn("Trump Tariffs Alleged", regexp_replace("Trump Tariffs Alleged", "%", "").cast("float"))
df = df.withColumn("Trump Response", regexp_replace("Trump Response", "%", "").cast("float"))

# %%
X = df[["Trump Tariffs Alleged"]]
y = df[["Trump Response"]]

# %%
X
# Out:
# DataFrame[Trump Tariffs Alleged: float]

# %%
Y
# Out:
# DataFrame[Trump_Response: string]

# %%
trainDF, testDF = df.randomSplit([.8,.2],seed=42)

# %%
assembler = VectorAssembler(inputCols=["Trump Tariffs Alleged"], outputCol="features")
trainDF = assembler.transform(trainDF)
testDF = assembler.transform(testDF)

# %%
lr = LinearRegression(featuresCol="features", labelCol="Trump Response")
model = lr.fit(trainDF)

# %%
prediction = model.transform(testDF)
prediction.select("Trump Tariffs Alleged", "Trump Response", "prediction").show(10)

print("RMSE:", model.summary.rootMeanSquaredError)
# Out:
# +---------------------+--------------+------------------+
# |Trump Tariffs Alleged|Trump Response|        prediction|
# +---------------------+--------------+------------------+
# |                 59.0|          29.0|30.104156402306927|
# |                 10.0|          10.0| 9.537606552954635|
# |                 10.0|          10.0| 9.537606552954635|
# |                 10.0|          10.0| 9.537606552954635|
# |                 10.0|          10.0| 9.537606552954635|
# |                 74.0|          37.0|  36.4000390092515|
# |                 88.0|          44.0| 42.27619610906644|
# |                 10.0|          10.0| 9.537606552954635|
# |                 22.0|          11.0|14.574312638510298|
# |                 10.0|          10.0| 9.537606552954635|
# +---------------------+--------------+------------------+
# only showing top 10 rows
#
# RMSE: 1.1768521597896893

# %%
import matplotlib.pyplot as plt

original_data = df.select("Trump Tarriffs Alleged", "Trump Response").dropna().collect()
x1 = [row[0] for row in original_data]
y1 = [row[1] for row in original_data]


pred_data = df.select("Trump Tarriffs Alleged", "prediction").dropna().collect()
x2 = [row[0] for row in pred_data]
y2 = [row[1] for row in pred_data]

plt.figure(figsize=(8, 6))
plt.scatter(x1, y1, alpha=0.6)
plt.title("Sample Data")
plt.xlabel("Trump's Alleged Tarriff")
plt.ylabel("Actual Tarriff")
plt.show()


plt.figure(figsize=(8, 6))
plt.scatter(x2, y2, alpha=0.6)
plt.title("Prediction Data")
plt.xlabel("Trump's Alleged Tarriff")
plt.ylabel("Actual Predicted Tarriff")
plt.show()
